# %%
import requests
from bs4 import BeautifulSoup

web = requests.get("https://udn.com/news/cate/2/7225")
content = BeautifulSoup(web.text, "html.parser")
allTitle = content.select(".story-list__text h2")
title_list = []

for i in allTitle[3:]:
    title_list.append(i.text[1:-1])

print(title_list)
# Out:
# ['烏克蘭破壞北溪天然氣管線？外洩情報曝：美國提早3個月就知情', '烏克蘭大壩遭炸毀 白宮：尚無法確定誰下毒手', '票在手、跟我走！土耳其總統如何打造「必勝選制」？', '控協助伊朗發展飛彈 美制裁中港伊朗個人與實體', '亂象頻傳！印度288死火車意外「仍有83具遺體無人認領」', '南韓當選安理會理事國  料將強化牽制北韓', '關閉7年！伊朗重啟駐沙烏地大使館', '沒那麼容易被AI取代？ChatGPT與新聞業的相愛相殺', '怎樣都睡不好？ 專家示範週五～週日這三天如何調整睡眠習慣', '孤單增加死亡風險！ 研究發現孤獨感與癌症生存率降低有關', '氣候暖化加劇！新研究：北極海冰可能在2030年代夏季完全消失', '大馬最綠男！交往8年女友劈腿4次 這回看到鹹濕簡訊終於放生', '影／誤把強力膠當眼藥水！左眼皮慘遭緊黏 醫拿金屬工具撬開', '膽小者別看！牆上驚見「超巨大蜈蚣」 網友發毛：這是真的嗎？', '螢光髮色美出新高度！櫻花妹逛水族館成「最亮焦點」 她崩潰：快哭了', '女子一年多來都喝「精液咖啡」 狼醫被逮宣稱打飛機忘記洗手', '航空公司認錯人！出國前晚機位突被取消 他「1原因」衰成奧客被禁飛10年', '憂北京蒐集情報 英政府將移除海康威視、大華監視設備', '標普500指數挑戰4,300點？前路有四大障礙', '蘋果CEO有沒有在用ChatGPT？庫克回答：當然有', '全球4月晶片銷售又萎縮超過20% 記憶體晶片尤其疲弱', '小型股領軍 標普500指數和那斯達克雙雙創高', '加拿大東岸野火燒不停 紐約空污嚴重一片灰濛', '新澤西州前州長欲問鼎白宮 川普黨內對手再加一', '高爾夫球界大震驚！ PGA、LIV同意合併 台灣供應商料受惠', '加拿大山火煙霧蔓延 紐約空氣品質亮紅燈', '潘斯參選美總統 挑戰前搭檔川普']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import jieba

# 將標題列表轉換為文字串接
text = ' '.join(title_list)

# 中文分詞
seg_list = jieba.cut(text, cut_all=False)
seg_list = list(seg_list)

# 設定字體路徑
font_path = 'C:/Windows/Fonts/msjh.ttc'


# 使用 WordCloud 產生文字雲
wordcloud = WordCloud(background_color='white', width=800, height=600, font_path='msjh.ttc', max_words=100, max_font_size=100).generate(text)

# 顯示文字雲
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
