# %%
import requests
from bs4 import BeautifulSoup

web = requests.get("https://udn.com/news/cate/2/7225")
content = BeautifulSoup(web.text, "html.parser")
allTitle = content.select(".story-list__text h2")
title_list = []

for i in allTitle[3:]:
    title_list.append(i.text[1:-1])

print(title_list)
# Out:
# ['烏急需砲彈反攻俄 美如何拉攏日本相助？', '郭崇倫會客室EP110｜切身相關或是冷眼旁觀 從歐洲觀點看俄烏戰', '20年來最慘重...印度3列火車相撞逾200死 倖存者：我活著但身邊人死了', '開歷史先例！教宗方濟各9月初訪蒙古 恐離不開大陸話題', '美國防長批北京拒絕對話 陸高官曝：美方沒做到「這事」', '美中情局長秘密訪問大陸 蘇利文：願意不帶先決條件與陸接觸', '「香格里拉對話」美中防長互動引關注 黃永宏：雙方有意願恢復對話', '吐槽年輕員工玻璃心「教不得」 女主管嘆：難道要把步驟拍成TikTok？', '2歲就被性侵！英國女親吐童年惡夢 狼父逼她翹課只為滿足自己', '誘殺補教師「分屍裝行李箱」 南韓冷血女被逮竟稱：我想殺人', '傳染性大增！禽流感病毒變異迅速 專家示警：哺乳動物病例數攀升', '日新幹線暴雨後復駛！東京、大阪、名古屋站仍混亂 逾5000人滯留車站', '男友嫌屁股不夠翹！她找上密醫手術 結果因填充物位移中風喪命', '影／3天大寶寶能抬頭還會爬 媽媽嚇壞：這樣正常嗎？', '人妻用母奶做點心 公公大讚「好想吃」被拒絕後竟直接偷吃', '鏡頭直擊22歲妻溜入老爸房 離婚後懷雙胞胎 綠帽男崩潰稱呼好亂', '尼加拉瓜湖現「蚊子龍捲風」畫面驚人 專家解釋原因', '投資人別錯過！巴隆點名5大熱門趨勢 專家呼籲：布局宜趁早', '馬斯克置頂反跨性別者影片 推特安全主管被證實已辭職', '白宮國安顧問：美會嘗試拉大陸進限武談判', '隱藏版潛力股！「這家」AI公司對ChatGPT沒興趣 直攻更大AI商機', '美股隨AI熱上漲！掃空Fed升息和經濟疑慮 法人分析：這幾檔沒漲才驚訝', '艾爾·帕西諾83歲再當爸懷疑胎兒非親生？傳要求29歲女友產前驗DNA', '罷工前兆？勞資薪酬協商談不攏 洛杉磯等美西港口作業停擺', '連100日3餐只吃麥當勞！體重破百男狂甩肉27公斤 營養師這麼說', '氣象專家預估：今年至少9颶風襲擊紐約市', '天才老爹又遭控 54年前下藥性侵玩伴女郎']

# %%
import json

output = []  # 用來存放每篇文章的標題
for i in allTitle[3:]:
    output.append(i.a.string)

# 將結果轉成JSON格式
json_output = json.dumps(output, ensure_ascii=False)

# 寫入檔案
with open('output.json', 'w', encoding='utf-8') as f:
    f.write(json_output)
    
json_output
# Out:
# '["烏急需砲彈反攻俄 美如何拉攏日本相助？", "郭崇倫會客室EP110｜切身相關或是冷眼旁觀 從歐洲觀點看俄烏戰", "20年來最慘重...印度3列火車相撞逾200死 倖存者：我活著但身邊人死了", "開歷史先例！教宗方濟各9月初訪蒙古 恐離不開大陸話題", "美國防長批北京拒絕對話 陸高官曝：美方沒做到「這事」", "美中情局長秘密訪問大陸 蘇利文：願意不帶先決條件與陸接觸", "「香格里拉對話」美中防長互動引關注 黃永宏：雙方有意願恢復對話", "吐槽年輕員工玻璃心「教不得」 女主管嘆：難道要把步驟拍成TikTok？", "2歲就被性侵！英國女親吐童年惡夢 狼父逼她翹課只為滿足自己", "誘殺補教師「分屍裝行李箱」 南韓冷血女被逮竟稱：我想殺人", "傳染性大增！禽流感病毒變異迅速 專家示警：哺乳動物病例數攀升", "日新幹線暴雨後復駛！東京、大阪、名古屋站仍混亂 逾5000人滯留車站", "男友嫌屁股不夠翹！她找上密醫手術 結果因填充物位移中風喪命", "影／3天大寶寶能抬頭還會爬 媽媽嚇壞：這樣正常嗎？", "人妻用母奶做點心 公公大讚「好想吃」被拒絕後竟直接偷吃", "鏡頭直擊22歲妻溜入老爸房 離婚後懷雙胞胎 綠帽男崩潰稱呼好亂", "尼加拉瓜湖現「蚊子龍捲風」畫面驚人 專家解釋原因", "投資人別錯過！巴隆點名5大熱門趨勢 專家呼籲：布局宜趁早", "馬斯克置頂反跨性別者影片 推特安全主管被證實已辭職", "白宮國安顧問：美會嘗試拉大陸進限武談判", "隱藏版潛力股！「這家」AI公司對ChatGPT沒興趣 直攻更大AI商機", "美股隨AI熱上漲！掃空Fed升息和經濟疑慮 法人分析：這幾檔沒漲才驚訝", "艾爾·帕西諾83歲再當爸懷疑胎兒非親生？傳要求29歲女友產前驗DNA", "罷工前兆？勞資薪酬協商談不攏 洛杉磯等美西港口作業停擺", "連100日3餐只吃麥當勞！體重破百男狂甩肉27公斤 營養師這麼說", "氣象專家預估：今年至少9颶風襲擊紐約市", "天才老爹又遭控 54年前下藥性侵玩伴女郎"]'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 將標題列表轉換為文字串接
text = ' '.join(title_list)

# 中文分詞
seg_list = jieba.cut(text, cut_all=False)
seg_list = list(seg_list)

# 設定字體路徑
font_path = 'C:/Windows/Fonts/msjh.ttc'


# 使用 WordCloud 產生文字雲
wordcloud = WordCloud(background_color='white', width=800, height=600, font_path='msjh.ttc', max_words=100, max_font_size=100).generate(text)

# 顯示文字雲
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
