# %%
import pandas as pd
# read csv file
nation = pd.read_csv("nation.csv", encoding="utf-8")

# %%
nation
# Out:
#    District/township/town/city  NOC_CountryRegion  Alpha-2 code   year  \
# 0          Melbourne/Stockholm                AUS            AS   1956
# 1                       Sydney                AUS            AS   2000
# 2                    Innsbruck                AUT            AT   1964
# 3                    Innsbruck                AUT            AT   1976
# 4                      Antwerp                BEL            BE   1920
# 5                      Antwerp                BEL            BE   1920
# 6                     Montreal                CAN            CA   1976
# 7                  Lake Placid                CAN            CA   1980
# 8                      Calgary                CAN            CA   1988
# 9                   St. Moritz                SUI            SZ   1928
# 10                  St. Moritz                SUI            SZ   1948
# 11                     Beijing                CHN            CH   2008
# ...

# %%
alldata1 = list(nation[' season'])
alldata1
# Out:
# ['summer',
#  ' summer',
#  ' winter',
#  ' winter',
#  ' summer',
#  ' winter',
#  ' Summer',
#  ' Winter',
#  ' Winter',
#  ' Winter',
#  ' Winter',
#  ' summer',
#  ' summer',
#  ' winter',
#  ' summer']

# %%
A1 = {'summer', ' summer', ' winter', ' winter', ' summer', ' winter', ' Summer', ' Winter', ' Winter', ' Winter', ' Winter', ' summer', ' summer', ' winter', ' summer'}
A2 = {' winter', ' Summer', ' Winter'}

print (A1&A2)
print (A1|A2)
print (A1-A2)
print ((A1|A2)-(A1&A2))
# Out:
# {' winter', ' Winter', ' Summer'}
# {' summer', ' winter', 'summer', ' Summer', ' Winter'}
# {' summer', 'summer'}
# {' summer', 'summer'}

# %%
import pandas as pd
# read csv file
nation = pd.read_csv("nation.csv", encoding="utf-8")
